# %% [markdown]
# # ㅁ

# %% [markdown]
# **Import Necessary Libraries**

# %%
# !pip install flask==0.12.2 --quiet
# !pip install flask-ngrok --quiet
print("Completed!")
# Out:
#      |████████████████████████████████| 83 kB 1.2 MB/s
# Completed!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Flask/
# !ls
# Out:
# /content/drive/MyDrive/Flask
# app.py			      ngrok-stable-linux-amd64.tgz.1  src_ref
# Flask_App_Tutorial.ipynb      ngrok-stable-linux-amd64.tgz.2  static
# ngrok			      ngrok-stable-linux-amd64.tgz.3  templates
# ngrok-stable-linux-amd64.tgz  README.md

# %% [markdown]
# **Setup and Installation of Ngrok**

# %%
# install ngrok linux version using the following command or you can get the
# latest version from its official website- https://dashboard.ngrok.com/get-started/setup

# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.tgz
# Out:
# --2022-07-20 00:57:59--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.tgz
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 54.237.133.81, 52.202.168.65, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13770165 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.tgz.4’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  5.23MB/s    in 2.5s
#
# 2022-07-20 00:58:02 (5.23 MB/s) - ‘ngrok-stable-linux-amd64.tgz.4’ saved [13770165/13770165]

# %%
# extract the downloaded file using the following command 

# !tar -xvf ./ngrok-stable-linux-amd64.tgz
# Out:
# ngrok

# %% [markdown]
# **The next step is to get your AuthToken from ngrok using this link-** https://dashboard.ngrok.com/get-started/your-authtoken

# %%
# paste your AuthToken here and execute this command

# !./ngrok authtoken 2CBYnczfaW15EhH9ZZLBQlP0Usz_7Khz38aSH53s4GbrDs3NY
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# import Flask from flask module
from flask import Flask, render_template, request, send_file
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from werkzeug.utils import secure_filename

# import run_with_ngrok from flask_ngrok to run the app using ngrok
from flask_ngrok import run_with_ngrok
  
app = Flask(__name__) #app name
run_with_ngrok(app)
  
@app.route('/')
def index():
    menu = {'home': 1, 'menu1': 0, 'menu2': 0}

    return render_template('index.html', menu=menu)


@app.route('/menu1', methods=['GET', 'POST'])    # 춤 일치도 분석
def menu1():
    menu = {'home': 0, 'menu1': 1, 'menu2': 0}
    if request.method == 'GET' :
        return render_template('menu1.html', menu=menu)
    else :
        # 변수1 = request.form['변수1']
        # 변수2 = request.form['변수2']
        # ...
        # 사용자함수(변수1, 변수2, ...)
        
        # return render_template('menu2_res.html', 변수1=, 변수2=, ...)
        return render_template('menu1_res.html', menu=menu)


@app.route('/menu2', methods=['GET', 'POST'])    # 춤 입히기
def menu2():
    menu = {'home': 0, 'menu1': 0, 'menu2': 1}
    if request.method == 'GET':
        return render_template('menu2.html', menu=menu)
    else:
        # 변수1 = request.form['변수1']
        # 변수2 = request.form['변수2']
        # ...
        # 사용자함수(변수1, 변수2, ...)
        
        # return render_template('menu2_res.html', 변수1=, 변수2=, ...)
        return render_template('menu2_res.html', menu=menu)
  
if __name__ == "__main__":
    app.run()
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://486b-34-135-178-178.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
